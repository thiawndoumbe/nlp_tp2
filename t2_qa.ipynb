# %% [markdown]
# # **Tâche #2 - Questions-réponses avec un modèle QA extractif**
#
# Cette tâche consiste à utiliser un modèle de question-réponse extractif de type transformer afin de repérer des informations dans un texte. Vous utilisez la librairie HuggingFace pour accomplir cette tâche. On demande plus spécifiquement d’utiliser le modèle *bert-base-uncased-whole-word-masking-finetuned-squad*.
#
# La tâche a pour but précis de repérer 3 informations dans les descriptions textuelles : le lieu et la date de l’incident ainsi qu’un court passage de texte indiquant ce qui s’est passé.  Une partie importante de votre travail consiste à trouver de bonnes formulations de questions pour repérer ces informations. Le fichier *t2_qa_examples*.json, qui contient 25 exemples annotés par un humain, est disponible pour mener vos expérimentations.
#
# Les consignes pour cette tâche sont:
# -	Nom du notebook : *t2_qa.ipynb* (ce notebook)
# -	Tokenisation et plongements de mots : Ceux du modèle utilisé.
# -	Normalisation : Aucune normalisation à faire (le tokeniseur convertit les lettres en minuscule).
# -	Construction du modèle : vous utilisez la version préentraînée du modèle sans modification. Aucun affinement (fine-tuning) du modèle n’est requis pour cette tâche.
# -	Évaluation : Du code est disponible dans le notebook pour évaluer la performance du modèle avec les métriques *exact match* et *F1*.
# -	Analyse : Présentez et discutez des résultats que vous obtenez pour les 3 types d’informations à repérer. Discutez également de vos choix de questions pour accomplir cette tâche et les erreurs commises par le modèle QA.

# %% [markdown]
# Vous pouvez ajouter au notebook toutes les cellules dont vous avez besoin pour votre code, vos explications ou la présentation de vos résultats. Vous pouvez également ajouter des sous-sections (par ex. des sous-sections 1.1, 1.2 etc.) si cela améliore la lisibilité.
#
# Notes :
# - Évitez les bouts de code trop longs ou trop complexes. Par exemple, il est difficile de comprendre 4-5 boucles ou conditions imbriquées. Si c'est le cas, définissez des sous-fonctions pour refactoriser et simplifier votre code.
# - Expliquez sommairement votre démarche.
# - Expliquez les choix que vous faites au niveau de la programmation et des modèles (si non trivial).
# - Analysez vos résultats. Indiquez ce que vous observez, si c'est bon ou non, si c'est surprenant, etc.
# - Une analyse quantitative et qualitative d'erreurs est intéressante et permet de mieux comprendre le comportement d'un modèle.

# %% [markdown]
# ## 1. Le chargement des données
#
# Utilisez le fichier ***/data/t2_qa_examples.json*** pour mener vos expérimentations.

# %%
import json

def load_json_data(filename):
    with open(filename, 'r') as fp:
        data = json.load(fp)
    return data

# %%
data = load_json_data('data/t2_qa_examples.json')
text = list(map(lambda x: x['text'], data))
expected_when = list(map(lambda x: x['WHEN'], data))
expected_where = list(map(lambda x: x['WHERE'], data))
expected_event = list(map(lambda x: x['EVENT'], data))
print(data)
# Out:
# [{'text': ' At around 10:00 p.m. on November 10  2013  Employee #1  with Villager  Construction Inc.  with a coworker  were using an asphalt milling machine  (Wirtgen; Model Number: W2100) to grind out existing asphalt from an  interstate at a railroad bridge overpass. Employee # 1 was standing on the  ground  checking the depth of the cut into the asphalt  using a handheld  pendant attached to the machine. The pedant could stretch out from ten to 15  ft. This allowed Employee #1 to walk back and forth  checking the cut. The  operator was on the top of the milling machine  controlling the operation of  the machine and ensuring that the milling machine and dump truck (driven by a  second coworker  who worked for an independent trucking service) kept a safe  working distance. A different company  Protective Services Inc. (PSI)  was  responsible for the traffic control of the job site and had shut down the  inside lane of a three lane section of the interstate  so that work could be  conducted on that lane. The entire work zone was approximately two miles long   from start to finish. Employee #1 and the operator of the milling machine had  completed milling four sections (eight total passes) of the inside lane at the  bridge overpasses and were waiting for PSI to shut down the center lane. Dual  lane shut down of the inside and center lanes of the interstate was completed  around 9:30 p.m.  and Employee #1 and the milling machine operator milled two  sections (four total passes) of the center lane. Once both sides of the  overpass were milled out  approximately 200 ft on each side  Employee #1 and  the operator of the milling machine moved the milling machine down the  interstate  approximately1 000 ft  to a railroad overpass and began setting up  to mill the center lane sections. The truck driver backed his truck into  position and remained in the truck to move the truck slowly forward as milling  took place. Employee #1 was positioned between the milling machine and the  concrete median dividers  inside the coned off work zone. The lanes of travel  were approximately 12 ft wide  so the milling machine made two passes  since  it can only cut seven ft wide on each section to cover the entire lane.  Employee #1 was standing approximately three ft in the far inside lane on the  ground between milling machine and interior median wall inside of the approved  traffic control set up  and approximately midway up the machine and 17 ft from  the traffic control devices and flow of traffic. The milling machine was  approximately nine ft wide by 50 ft long  while operating. Employee #1 was  guarded by the machine from the flow of traffic. Approximately five to ten  minutes into the first pass  the milling machine operator noticed lights  hitting the reflectors on the inside wall and turned briefly to see a vehicle  coming. The operator thought it was the Project manager coming to check on the  status of the project. Then  the operator realized that the oncoming vehicle  was not equipped with a strobe  as required in work zones. The operator turned  and yelled for Employee # 1 to run for safety  as a Chevrolet Tahoe came down  the inside lane where Employee #1 was standing. The driver of the Tahoe  continued traveling in the far inside lane of the work zone  where Employee #1  was struck and thrown some 100 ft from where he was originally standing. The  vehicle was moving approximately 45 mph per hour. As he was transferred to a  hospital by emergency personnel  Employee #1 was treated for severe trauma   lacerations  fractures  and contusions to the body and head. Employee #1 was  pronounced dead at the hospital. The driver of the vehicle disregarded the  traffic control set up  all warning lights on the rear of the milling machine   and cone spacing of 100 ft. The construction work zone was set up correctly  with all signage  cone spacing  tapering  attenuators  and lighting; all of  the traffic control set up was approved by MUTCD for thi ...

# %% [markdown]
# ## 2. Vos questions
#
# Vous pouvez mettre plusieurs options de questions dans le notebook. Il est important de présenter, au minimum, les résultats pour le meilleur jeu de questions. Vous pourrez également mettre des informations à ce propos dans la section d'analyse.

# %%
questions_when = [
    "When?",
    "When did the event happen?",
    "What date did the event happen?",
    "What date did the event happen? If no specific date is mentioned, return an empty string.",
]

# %%
questions_where = [
    "Where did the event happen?",
    "Where did the incident happen?",
    "Where did it happen?",
    "Name the place where the event happened.",
    "Name the place where the incident happened.",
    "Describe the place where the incident happened.",
    "Find the place where the incident happened.",
    "Identify the place where the incident happened.",
    "Where did the event occured?",
    "Where did the event take place?",
    "Where did the event was located?",
    "Where did the event emerged?",
    "What place did the event occured?",
    "What place did the event occur?",
    "Where?"
]

# %%
questions_event = [
    "What?",
    "What is the event?",
    "What is the incident?",
    "What incident has the employee suffered?",
    "What incident has the employee experienced?",
    "What incident has the employee experienced? Mention if it is the employee #1 that has experienced the incident.",
    "Identify the incident that occurred.",
    "Identify and summerize the incident that occurred.",
    "Identify and summerize the incident that the employee experienced.",
    "Identify and summerize the consequences of the incident.",
    "What is the injury that the employee has suffered?",
    "what caused the injury?",
    "What is the cause of the incident?",
    "What is the cause of the injury?",
    "Who was involved in the incident and what happened?",
    "Summerize the incident",
    "Summerize the incident that occurred",
    "Summerize the incident and the consequences",
]

# %% [markdown]
# ## 3. Le modèle de question-réponse extractif

# %%
from transformers import pipeline

model_name = "google-bert/bert-large-uncased-whole-word-masking-finetuned-squad"

model = pipeline(model=model_name, task='question-answering')
# Out:
# Some weights of the model checkpoint at google-bert/bert-large-uncased-whole-word-masking-finetuned-squad were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Rouler la prédiction d'une question pour chaque rapport 
def predict(model, contexts, question):
    return [model(context=c, question=question) for c in contexts]

# %% [markdown]
# ## 4. Des fonctions utilitaires pour l'évaluation

# %%
import string
import re
from collections import Counter

def remove_articles(text):
    return re.sub(r'\b(a|an|the)\b', ' ', text)

def white_space_fix(text):
    return ' '.join(text.split())

def remove_punc(text):
    exclude = set(string.punctuation)
    return ''.join(ch for ch in text if ch not in exclude)

def lower(text):
    return text.lower()

def normalize_answer(s):
    """Mettre en minuscule et retirer la ponctuation, des déterminants and les espaces."""
    return white_space_fix(remove_articles(remove_punc(lower(s))))

# %%
def evaluate_f1(ground_truth, prediction):
    """Normalise les 2 textes, trouve ce qu'il y a en commun et estime précision, rappel et F1."""
    prediction_tokens = normalize_answer(prediction).split()
    ground_truth_tokens = normalize_answer(ground_truth).split()
    common = Counter(prediction_tokens) & Counter(ground_truth_tokens)
    num_same = sum(common.values())
    if len(ground_truth_tokens) == 0 or len(prediction_tokens) == 0:
        return int(ground_truth_tokens == prediction_tokens)
    if num_same == 0:
        return 0
    precision = 1.0 * num_same / len(prediction_tokens)
    recall = 1.0 * num_same / len(ground_truth_tokens)
    f1 = (2 * precision * recall) / (precision + recall)
    return f1

def evaluate_exact_match(ground_truth, prediction):
    """Vérifie si les 2 textes sont quasi-identiques."""
    return (normalize_answer(prediction) == normalize_answer(ground_truth))

# %%
# Rouler la prédiction de la réponse pour chaque rapport et pour chaque questions 
def run(model, contexts, questions, answers):
    for question in questions:
        predictions = predict(model, contexts, question)
        
        # Calcul du F1 score et du exact match
        f1 = 0
        exact_match = 0
        for pred, answer in zip(predictions, answers):
            f1 += evaluate_f1(pred["answer"], answer)
            exact_match += 1 if evaluate_exact_match(pred["answer"], answer) else 0
        print(f"Question: {question}")
        print(f"F1 score: {f1}/{len(contexts)}")
        print(f"Exact match: {exact_match}/{len(contexts)}")
        
        # Lister tous les erreurs de prédictions
        for i, (p, e) in enumerate(zip(predictions, answers)):
            if p['answer'] != e:
                print(f"Prediction: {p} --- Expected: {e}")
        print()

# %% [markdown]
# ## 5. Évaluation du modèle et analyse

# %% [markdown]
# ### 5.1 When

# %%
run(model, text, questions_when, expected_when)
# Out:
# Question: When?
# F1 score: 23.0/25
# Exact match: 23/25
# Prediction: {'score': 0.2796871066093445, 'start': 155, 'end': 214, 'answer': 'when it bumped up against a ceiling pipe while being raised'} --- Expected:
# Prediction: {'score': 0.31268927454948425, 'start': 57, 'end': 64, 'answer': 'drowned'} --- Expected:
#
# Question: When did the event happen?
# F1 score: 23.0/25
# Exact match: 23/25
# Prediction: {'score': 0.13847969472408295, 'start': 155, 'end': 214, 'answer': 'when it bumped up against a ceiling pipe while being raised'} --- Expected:
# Prediction: {'score': 0.29438358545303345, 'start': 57, 'end': 64, 'answer': 'drowned'} --- Expected:
#
# Question: What date did the event happen?
# F1 score: 23.0/25
# Exact match: 23/25
# Prediction: {'score': 0.033587586134672165, 'start': 155, 'end': 214, 'answer': 'when it bumped up against a ceiling pipe while being raised'} --- Expected:
# Prediction: {'score': 0.3679411709308624, 'start': 57, 'end': 64, 'answer': 'drowned'} --- Expected:
#
# Question: What date did the event happen? If no specific date is mentioned, return an empty string.
# F1 score: 23.0/25
# Exact match: 23/25
# Prediction: {'score': 0.023814748972654343, 'start': 240, 'end': 268, 'answer': 'The wall fell on Employee #1'} --- Expected:
# Prediction: {'score': 0.3735562264919281, 'start': 57, 'end': 64, 'answer': 'drowned'} --- Expected:

# %% [markdown]
# ### 5.2 Where

# %%
run(model, text, questions_where, expected_where)
# Out:
# Question: Where did the event happen?
# F1 score: 19.919658119658123/25
# Exact match: 16/25
# Prediction: {'score': 0.10176228731870651, 'start': 193, 'end': 226, 'answer': 'process of mixing cement/concrete'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.0952552855014801, 'start': 193, 'end': 222, 'answer': 'Home Depot  Store Number 6555'} --- Expected: the garden center
# Prediction: {'score': 0.06973588466644287, 'start': 279, 'end': 349, 'answer': 'between the excavation wall and the  north wall of the inlet structure'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.023866726085543633, 'start': 42, 'end': 80, 'answer': 'building a wood frame detached  garage'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.026094749569892883, 'start': 401, 'end': 431, 'answer': 'Employee #1 entered the trench'} --- Expected: in the trench
# Prediction: {'score': 0.1536531150341034, 'start': 41, 'end': 72, 'answer': 'a trench  at a depth of 18 feet'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.08288194984197617, 'start': 134, 'end': 150, 'answer': '8 ft deep trench'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.01548050343990326, 'start': 513, 'end': 571, 'answer': 'Employee #1 was  working in a 7 ft deep part of the trench'} --- Expected: a new residential dwelling to a municipal tie-in point
# Prediction: {'score': 0.04661734774708748, 'start': 37, 'end': 86, 'answer': 'inside a 140-ft long and 24-in. in  diameter pipe'} --- Expected: tunnel underneath a highway
#
# Question: Where did the incident happen?
# F1 score: 15.294505494505495/25
# Exact match: 12/25
# Prediction: {'score': 0.08825529366731644, 'start': 193, 'end': 226, 'answer': 'process of mixing cement/concrete'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.15972651541233063, 'start': 461, 'end': 484, 'answer': "Employee #1's sign area"} --- Expected: one mile away
# Prediction: {'score': 0.07115411758422852, 'start': 987, 'end': 1026, 'answer': 'He was  walking west across the on-ramp'} --- Expected: Interstate 15 (I-15)  and approximately 14100 South
# Prediction: {'score': 0.06198285147547722, 'start': 193, 'end': 222, 'answer': 'Home Depot  Store Number 6555'} --- Expected: the garden center
# Prediction: {'score': 0.22593100368976593, 'start': 893, 'end': 924, 'answer': 'inside structure of the carport'} --- Expected: inside the freestanding carport
# Prediction: {'score': 0.10164050757884979, 'start': 618, 'end': 633, 'answer': 'the south  wall'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.14407214522361755, 'start': 660, 'end': 666, 'answer': 'buried'} --- Expected: trench
# Prediction: {'score': 0.033000797033309937, 'start': 303, 'end': 320, 'answer': 'a  local hospital'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.050961997359991074, 'start': 401, 'end': 431, 'answer': 'Employee #1 entered the trench'} --- Expected: in the trench
# Prediction: {'score': 0.18508152663707733, 'start': 41, 'end': 72, 'answer': 'a trench  at a depth of 18 feet'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.06142159923911095, 'start': 134, 'end': 150, 'answer': '8 ft deep trench'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.01812909170985222, 'start': 543, 'end': 589, 'answer': '7 ft deep part of the trench near a solid wall'} --- Expected: a new residential dwelling to a municipal tie-in point
# Prediction: {'score': 0.0761149674654007, 'start': 152, 'end': 167, 'answer': 'inside the pipe'} --- Expected: tunnel underneath a highway
#
# Question: Where did it happen?
# F1 score: 11.433333333333334/25
# Exact match: 10/25
# Prediction: {'score': 0.05158514901995659, 'start': 193, 'end': 226, 'answer': 'process of mixing cement/concrete'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.08503133803606033, 'start': 461, 'end': 484, 'answer': "Employee #1's sign area"} --- Expected: one mile away
# Prediction: {'score': 0.06997192651033401, 'start': 851, 'end': 894, 'answer': 'pinned between the loading dock and trailer'} --- Expected: Birds Eye Foods
# Prediction: {'score': 0.0669427365064621, 'start': 1060, 'end': 1085, 'answer': 'struck by the  dump truck'} --- Expected: Interstate 15 (I-15)  and approximately 14100 South
# Prediction: {'score': 0.015297729521989822, 'start': 1211, 'end': 1219, 'answer': 'asphyxia'} --- Expected: the garden center
# Prediction: {'score': 0.23391671478748322, 'start': 886, 'end': 924, 'answer': 'on the inside structure of the carport'} --- Expected: inside the freestanding carport
# Prediction: {'score': 0.12423428148031235, 'start': 554, 'end': 633, 'answer': 'south wall of the inlet structure  crushing Employee #1 against the south  wall'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.3057336211204529, 'start': 655, 'end': 666, 'answer': 'when buried'} --- Expected: trench
# Prediction: {'score': 0.07354585826396942, 'start': 303, 'end': 320, 'answer': 'a  local hospital'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.07600385695695877, 'start': 655, 'end': 671, 'answer': 'a local hospital'} --- Expected: in the trench
# Prediction: {'score': 0.06543486565351486, 'start': 181, 'end': 195, 'answer': 'a ceiling pipe'} --- Expected: a construction site
# Prediction: {'score': 0.14922328293323517, 'start': 287, 'end': 300, 'answer': 'Morton County'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.017742890864610672, 'start': 513, 'end': 571, 'answer': 'Employee #1 was  working in a 7 ft deep part of the trench'} --- Expected: a new residential dwelling to a municipal tie-in point
# Prediction: {'score': 0.14992958307266235, 'start': 1064, 'end': 1086, 'answer': 'capsized  both vessels'} --- Expected: a hopper  barge
# Prediction: {'score': 0.09452585130929947, 'start': 152, 'end': 167, 'answer': 'inside the pipe'} --- Expected: tunnel underneath a highway
#
# Question: Name the place where the event happened.
# F1 score: 15.423529411764706/25
# Exact match: 13/25
# Prediction: {'score': 0.1585836410522461, 'start': 284, 'end': 322, 'answer': 'St. James hospital in  Chicago Heights'} --- Expected: a bathroom  facility
# Prediction: {'score': 0.03773436322808266, 'start': 193, 'end': 226, 'answer': 'process of mixing cement/concrete'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.014106405898928642, 'start': 573, 'end': 592, 'answer': '14300 South on-ramp'} --- Expected: Interstate 15 (I-15)  and approximately 14100 South
# Prediction: {'score': 0.07792464643716812, 'start': 22, 'end': 77, 'answer': 'Employee #1 was working inside the freestanding carport'} --- Expected: inside the freestanding carport
# Prediction: {'score': 0.011664418503642082, 'start': 18, 'end': 45, 'answer': '7:15 a.m. on August 9  2007'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.02946547232568264, 'start': 46, 'end': 113, 'answer': 'Employee #1 was repairing a  pipeline for a new housing development'} --- Expected: trench
# Prediction: {'score': 0.3500373065471649, 'start': 303, 'end': 320, 'answer': 'a  local hospital'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.029618779197335243, 'start': 655, 'end': 671, 'answer': 'a local hospital'} --- Expected: in the trench
# Prediction: {'score': 0.058946214616298676, 'start': 22, 'end': 72, 'answer': 'Employee #1 was in a trench  at a depth of 18 feet'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.012970663607120514, 'start': 287, 'end': 300, 'answer': 'Morton County'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.006636712234467268, 'start': 661, 'end': 684, 'answer': 'Employee #1 was killed.'} --- Expected: a new residential dwelling to a municipal tie-in point
# Prediction: {'score': 0.011979974806308746, 'start': 614, 'end': 703, 'answer': 'The  barge was used to catch construction debris from a bridge that was being  demolished'} --- Expected: a hopper  barge
# Prediction: {'score': 0.3693808615207672, 'start': 116, 'end': 141, 'answer': 'residential swimming pool'} --- Expected: a residential swimming pool
#
# Question: Name the place where the incident happened.
# F1 score: 15.294505494505495/25
# Exact match: 13/25
# Prediction: {'score': 0.046553727239370346, 'start': 186, 'end': 226, 'answer': 'in the process of mixing cement/concrete'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.015482302755117416, 'start': 573, 'end': 592, 'answer': '14300 South on-ramp'} --- Expected: Interstate 15 (I-15)  and approximately 14100 South
# Prediction: {'score': 0.056835293769836426, 'start': 193, 'end': 222, 'answer': 'Home Depot  Store Number 6555'} --- Expected: the garden center
# Prediction: {'score': 0.07795853912830353, 'start': 22, 'end': 77, 'answer': 'Employee #1 was working inside the freestanding carport'} --- Expected: inside the freestanding carport
# Prediction: {'score': 0.022686390206217766, 'start': 18, 'end': 45, 'answer': '7:15 a.m. on August 9  2007'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.02541140653192997, 'start': 632, 'end': 666, 'answer': 'Employee #1 was killed when buried'} --- Expected: trench
# Prediction: {'score': 0.3791646957397461, 'start': 303, 'end': 320, 'answer': 'a  local hospital'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.07509051263332367, 'start': 655, 'end': 671, 'answer': 'a local hospital'} --- Expected: in the trench
# Prediction: {'score': 0.07549507915973663, 'start': 41, 'end': 72, 'answer': 'a trench  at a depth of 18 feet'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.029840711504220963, 'start': 287, 'end': 300, 'answer': 'Morton County'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.007869912311434746, 'start': 513, 'end': 571, 'answer': 'Employee #1 was  working in a 7 ft deep part of the trench'} --- Expected: a new residential dwelling to a municipal tie-in point
# Prediction: {'score': 0.021833794191479683, 'start': 18, 'end': 43, 'answer': '3:45 PM on April 18  2007'} --- Expected: a hopper  barge
# Prediction: {'score': 0.05329078808426857, 'start': 104, 'end': 133, 'answer': 'a tunnel underneath a highway'} --- Expected: tunnel underneath a highway
#
# Question: Describe the place where the incident happened.
# F1 score: 11.643442831678126/25
# Exact match: 8/25
# Prediction: {'score': 0.11301866173744202, 'start': 284, 'end': 322, 'answer': 'St. James hospital in  Chicago Heights'} --- Expected: a bathroom  facility
# Prediction: {'score': 0.06003955379128456, 'start': 186, 'end': 226, 'answer': 'in the process of mixing cement/concrete'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.016022244468331337, 'start': 461, 'end': 484, 'answer': "Employee #1's sign area"} --- Expected: one mile away
# Prediction: {'score': 0.26528364419937134, 'start': 148, 'end': 234, 'answer': 'The  equipment had been positioned in the emergency shoulder of an interstate  highway'} --- Expected: the emergency shoulder of an interstate  highway
# Prediction: {'score': 0.03881628438830376, 'start': 177, 'end': 229, 'answer': 'He parked his service truck in front of Bay Number 3'} --- Expected: Birds Eye Foods
# Prediction: {'score': 0.03376219794154167, 'start': 987, 'end': 1026, 'answer': 'He was  walking west across the on-ramp'} --- Expected: Interstate 15 (I-15)  and approximately 14100 South
# Prediction: {'score': 0.02141205035150051, 'start': 193, 'end': 222, 'answer': 'Home Depot  Store Number 6555'} --- Expected: the garden center
# Prediction: {'score': 0.04833367094397545, 'start': 22, 'end': 77, 'answer': 'Employee #1 was working inside the freestanding carport'} --- Expected: inside the freestanding carport
# Prediction: {'score': 0.02215520851314068, 'start': 589, 'end': 633, 'answer': 'crushing Employee #1 against the south  wall'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.049849968403577805, 'start': 632, 'end': 666, 'answer': 'Employee #1 was killed when buried'} --- Expected: trench
# Prediction: {'score': 0.05832219496369362, 'start': 303, 'end': 334, 'answer': 'a  local hospital for treatment'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.08243921399116516, 'start': 437, 'end': 500, 'answer': 'the trench wall and  spoil pile collapsed  covering Employee #1'} --- Expected: in the trench
# Prediction: {'score': 0.13233163952827454, 'start': 22, 'end': 72, 'answer': 'Employee #1 was in a trench  at a depth of 18 feet'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.025475721806287766, 'start': 134, 'end': 150, 'answer': '8 ft deep trench'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.01532801054418087, 'start': 513, 'end': 571, 'answer': 'Employee #1 was  working in a 7 ft deep part of the trench'} --- Expected: a new residential dwelling to a municipal tie-in point
# Prediction: {'score': 0.012871082872152328, 'start': 18, 'end': 43, 'answer': '3:45 PM on April 18  2007'} --- Expected: a hopper  barge
# Prediction: {'score': 0.0804445818066597, 'start': 135, 'end': 167, 'answer': 'Employee #1 was  inside the pipe'} --- Expected: tunnel underneath a highway
#
# Question: Find the place where the incident happened.
# F1 score: 12.73868092691622/25
# Exact match: 10/25
# Prediction: {'score': 0.012913437560200691, 'start': 156, 'end': 227, 'answer': 'cement mixer that tipped over in the process of mixing cement/concrete.'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.007473464123904705, 'start': 158, 'end': 169, 'answer': 'a pilot car'} --- Expected: one mile away
# Prediction: {'score': 0.15039841830730438, 'start': 148, 'end': 234, 'answer': 'The  equipment had been positioned in the emergency shoulder of an interstate  highway'} --- Expected: the emergency shoulder of an interstate  highway
# Prediction: {'score': 0.011732522398233414, 'start': 177, 'end': 230, 'answer': 'He parked his service truck in front of Bay Number 3.'} --- Expected: Birds Eye Foods
# Prediction: {'score': 0.008982231840491295, 'start': 443, 'end': 466, 'answer': 'According to  witnesses'} --- Expected: Interstate 15 (I-15)  and approximately 14100 South
# Prediction: {'score': 0.0767422690987587, 'start': 147, 'end': 167, 'answer': 'Alimack  hoist tower'} --- Expected: Alimack hoist tower
# Prediction: {'score': 0.004964662715792656, 'start': 193, 'end': 222, 'answer': 'Home Depot  Store Number 6555'} --- Expected: the garden center
# Prediction: {'score': 0.019759401679039, 'start': 22, 'end': 77, 'answer': 'Employee #1 was working inside the freestanding carport'} --- Expected: inside the freestanding carport
# Prediction: {'score': 0.02992153726518154, 'start': 589, 'end': 633, 'answer': 'crushing Employee #1 against the south  wall'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.05353168770670891, 'start': 632, 'end': 667, 'answer': 'Employee #1 was killed when buried.'} --- Expected: trench
# Prediction: {'score': 0.11459413170814514, 'start': 303, 'end': 320, 'answer': 'a  local hospital'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.022845294326543808, 'start': 437, 'end': 500, 'answer': 'the trench wall and  spoil pile collapsed  covering Employee #1'} --- Expected: in the trench
# Prediction: {'score': 0.03500644117593765, 'start': 22, 'end': 72, 'answer': 'Employee #1 was in a trench  at a depth of 18 feet'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.051240224391222, 'start': 181, 'end': 195, 'answer': 'a ceiling pipe'} --- Expected: a construction site
# Prediction: {'score': 0.009049516171216965, 'start': 213, 'end': 266, 'answer': 'the entire east  side caved in and buried Employee #1'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.008280469104647636, 'start': 661, 'end': 684, 'answer': 'Employee #1 was killed.'} --- Expected: a new residential dwelling to a municipal tie-in point
# Prediction: {'score': 0.0018204373773187399, 'start': 72, 'end': 85, 'answer': 'hopper  barge'} --- Expected: a hopper  barge
#
# Question: Identify the place where the incident happened.
# F1 score: 10.471437059672354/25
# Exact match: 6/25
# Prediction: {'score': 0.013558404520154, 'start': 193, 'end': 226, 'answer': 'process of mixing cement/concrete'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.009990773163735867, 'start': 145, 'end': 169, 'answer': 'location  of a pilot car'} --- Expected: one mile away
# Prediction: {'score': 0.13646936416625977, 'start': 148, 'end': 234, 'answer': 'The  equipment had been positioned in the emergency shoulder of an interstate  highway'} --- Expected: the emergency shoulder of an interstate  highway
# Prediction: {'score': 0.018168848007917404, 'start': 569, 'end': 615, 'answer': 'The truck driver had been in the sleeper berth'} --- Expected: Birds Eye Foods
# Prediction: {'score': 0.03624921664595604, 'start': 443, 'end': 466, 'answer': 'According to  witnesses'} --- Expected: Interstate 15 (I-15)  and approximately 14100 South
# Prediction: {'score': 0.04981565847992897, 'start': 116, 'end': 167, 'answer': 'Employee #1 was located in the Alimack  hoist tower'} --- Expected: Alimack hoist tower
# Prediction: {'score': 0.0018987024668604136, 'start': 193, 'end': 222, 'answer': 'Home Depot  Store Number 6555'} --- Expected: the garden center
# Prediction: {'score': 0.02286500297486782, 'start': 22, 'end': 77, 'answer': 'Employee #1 was working inside the freestanding carport'} --- Expected: inside the freestanding carport
# Prediction: {'score': 0.025439955294132233, 'start': 589, 'end': 633, 'answer': 'crushing Employee #1 against the south  wall'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.07503214478492737, 'start': 632, 'end': 667, 'answer': 'Employee #1 was killed when buried.'} --- Expected: trench
# Prediction: {'score': 0.04001862555742264, 'start': 303, 'end': 334, 'answer': 'a  local hospital for treatment'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.04976803809404373, 'start': 437, 'end': 500, 'answer': 'the trench wall and  spoil pile collapsed  covering Employee #1'} --- Expected: in the trench
# Prediction: {'score': 0.04949251934885979, 'start': 22, 'end': 72, 'answer': 'Employee #1 was in a trench  at a depth of 18 feet'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.02863258682191372, 'start': 1, 'end': 62, 'answer': 'Employee #1  an independent contractor at a construction site'} --- Expected: a construction site
# Prediction: {'score': 0.014888400211930275, 'start': 153, 'end': 207, 'answer': 'A coworker had just left the trench to get a connector'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.015385652892291546, 'start': 661, 'end': 684, 'answer': 'Employee #1 was killed.'} --- Expected: a new residential dwelling to a municipal tie-in point
# Prediction: {'score': 0.0034365812316536903, 'start': 18, 'end': 43, 'answer': '3:45 PM on April 18  2007'} --- Expected: a hopper  barge
# Prediction: {'score': 0.04957916587591171, 'start': 135, 'end': 167, 'answer': 'Employee #1 was  inside the pipe'} --- Expected: tunnel underneath a highway
# Prediction: {'score': 0.06644076108932495, 'start': 1, 'end': 52, 'answer': 'Employee #1  a diver  became caught in a coffer dam'} --- Expected: a coffer dam
#
# Question: Where did the event occured?
# F1 score: 19.786324786324787/25
# Exact match: 17/25
# Prediction: {'score': 0.0766180157661438, 'start': 193, 'end': 226, 'answer': 'process of mixing cement/concrete'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.18596991896629333, 'start': 193, 'end': 222, 'answer': 'Home Depot  Store Number 6555'} --- Expected: the garden center
# Prediction: {'score': 0.15252454578876495, 'start': 279, 'end': 349, 'answer': 'between the excavation wall and the  north wall of the inlet structure'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.0420718714594841, 'start': 46, 'end': 113, 'answer': 'Employee #1 was repairing a  pipeline for a new housing development'} --- Expected: trench
# Prediction: {'score': 0.043311286717653275, 'start': 42, 'end': 80, 'answer': 'building a wood frame detached  garage'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.02411775290966034, 'start': 150, 'end': 167, 'answer': 'trenching project'} --- Expected: in the trench
# Prediction: {'score': 0.19416135549545288, 'start': 41, 'end': 72, 'answer': 'a trench  at a depth of 18 feet'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.1283680647611618, 'start': 287, 'end': 300, 'answer': 'Morton County'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.07307309657335281, 'start': 104, 'end': 133, 'answer': 'a tunnel underneath a highway'} --- Expected: tunnel underneath a highway
#
# Question: Where did the event take place?
# F1 score: 19.815082956259428/25
# Exact match: 17/25
# Prediction: {'score': 0.19338427484035492, 'start': 66, 'end': 88, 'answer': 'Midwest  Masonry  Inc.'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.04835947975516319, 'start': 250, 'end': 301, 'answer': 'Utah County line to 12300 South in Salt Lake County'} --- Expected: Interstate 15 (I-15)  and approximately 14100 South
# Prediction: {'score': 0.26692402362823486, 'start': 193, 'end': 222, 'answer': 'Home Depot  Store Number 6555'} --- Expected: the garden center
# Prediction: {'score': 0.12546789646148682, 'start': 279, 'end': 349, 'answer': 'between the excavation wall and the  north wall of the inlet structure'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.09683199971914291, 'start': 88, 'end': 113, 'answer': 'a new housing development'} --- Expected: trench
# Prediction: {'score': 0.047905463725328445, 'start': 53, 'end': 80, 'answer': 'wood frame detached  garage'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.04237651452422142, 'start': 240, 'end': 246, 'answer': 'trench'} --- Expected: in the trench
# Prediction: {'score': 0.15528550744056702, 'start': 41, 'end': 72, 'answer': 'a trench  at a depth of 18 feet'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.21353518962860107, 'start': 134, 'end': 150, 'answer': '8 ft deep trench'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.5070686340332031, 'start': 116, 'end': 141, 'answer': 'residential swimming pool'} --- Expected: a residential swimming pool
#
# Question: Where did the event was located?
# F1 score: 16.193593334769808/25
# Exact match: 12/25
# Prediction: {'score': 0.4044332504272461, 'start': 307, 'end': 322, 'answer': 'Chicago Heights'} --- Expected: a bathroom  facility
# Prediction: {'score': 0.30468085408210754, 'start': 66, 'end': 88, 'answer': 'Midwest  Masonry  Inc.'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.27543750405311584, 'start': 250, 'end': 277, 'answer': 'approximately one mile away'} --- Expected: one mile away
# Prediction: {'score': 0.15293508768081665, 'start': 250, 'end': 301, 'answer': 'Utah County line to 12300 South in Salt Lake County'} --- Expected: Interstate 15 (I-15)  and approximately 14100 South
# Prediction: {'score': 0.29004546999931335, 'start': 193, 'end': 222, 'answer': 'Home Depot  Store Number 6555'} --- Expected: the garden center
# Prediction: {'score': 0.3614335060119629, 'start': 57, 'end': 77, 'answer': 'freestanding carport'} --- Expected: inside the freestanding carport
# Prediction: {'score': 0.06618969887495041, 'start': 279, 'end': 349, 'answer': 'between the excavation wall and the  north wall of the inlet structure'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.05263909697532654, 'start': 40, 'end': 113, 'answer': '2011  Employee #1 was repairing a  pipeline for a new housing development'} --- Expected: trench
# Prediction: {'score': 0.03293173387646675, 'start': 12, 'end': 80, 'answer': '2009  Employee #1 and #2 were building a wood frame detached  garage'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.029521869495511055, 'start': 657, 'end': 671, 'answer': 'local hospital'} --- Expected: in the trench
# Prediction: {'score': 0.05602802336215973, 'start': 16, 'end': 72, 'answer': '2009  Employee #1 was in a trench  at a depth of 18 feet'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.5074672698974609, 'start': 287, 'end': 300, 'answer': 'Morton County'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.28346967697143555, 'start': 113, 'end': 133, 'answer': 'underneath a highway'} --- Expected: tunnel underneath a highway
# Prediction: {'score': 0.6197611093521118, 'start': 116, 'end': 141, 'answer': 'residential swimming pool'} --- Expected: a residential swimming pool
#
# Question: Where did the event emerged?
# F1 score: 16.75867269984917/25
# Exact match: 16/25
# Prediction: {'score': 0.40716731548309326, 'start': 307, 'end': 322, 'answer': 'Chicago Heights'} --- Expected: a bathroom  facility
# Prediction: {'score': 0.034986887127161026, 'start': 644, 'end': 690, 'answer': 'the ditch area at the north edge of the street'} --- Expected: one mile away
# Prediction: {'score': 0.13668061792850494, 'start': 250, 'end': 301, 'answer': 'Utah County line to 12300 South in Salt Lake County'} --- Expected: Interstate 15 (I-15)  and approximately 14100 South
# Prediction: {'score': 0.03244912624359131, 'start': 679, 'end': 692, 'answer': 'garden center'} --- Expected: the garden center
# Prediction: {'score': 0.4939849376678467, 'start': 279, 'end': 349, 'answer': 'between the excavation wall and the  north wall of the inlet structure'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.05002167075872421, 'start': 303, 'end': 320, 'answer': 'a  local hospital'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.03851497173309326, 'start': 401, 'end': 431, 'answer': 'Employee #1 entered the trench'} --- Expected: in the trench
# Prediction: {'score': 0.12774376571178436, 'start': 195, 'end': 232, 'answer': 'The local fire and ambulance  service'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.10081120580434799, 'start': 181, 'end': 195, 'answer': 'a ceiling pipe'} --- Expected: a construction site
# Prediction: {'score': 0.3134768307209015, 'start': 287, 'end': 300, 'answer': 'Morton County'} --- Expected: in an approximately 8 ft deep trench
#
# Question: What place did the event occured?
# F1 score: 20.462698412698415/25
# Exact match: 17/25
# Prediction: {'score': 0.13500067591667175, 'start': 189, 'end': 226, 'answer': 'the process of mixing cement/concrete'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.1997942328453064, 'start': 193, 'end': 222, 'answer': 'Home Depot  Store Number 6555'} --- Expected: the garden center
# Prediction: {'score': 0.055274538695812225, 'start': 181, 'end': 205, 'answer': 'drainage inlet structure'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.0547407791018486, 'start': 88, 'end': 113, 'answer': 'a new housing development'} --- Expected: trench
# Prediction: {'score': 0.047213468700647354, 'start': 42, 'end': 80, 'answer': 'building a wood frame detached  garage'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.08539377897977829, 'start': 150, 'end': 167, 'answer': 'trenching project'} --- Expected: in the trench
# Prediction: {'score': 0.2608615458011627, 'start': 41, 'end': 49, 'answer': 'a trench'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.14378434419631958, 'start': 134, 'end': 150, 'answer': '8 ft deep trench'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.14433981478214264, 'start': 104, 'end': 133, 'answer': 'a tunnel underneath a highway'} --- Expected: tunnel underneath a highway
# Prediction: {'score': 0.4654274582862854, 'start': 116, 'end': 141, 'answer': 'residential swimming pool'} --- Expected: a residential swimming pool
#
# Question: What place did the event occur?
# F1 score: 19.81800976800977/25
# Exact match: 17/25
# Prediction: {'score': 0.22587566077709198, 'start': 186, 'end': 226, 'answer': 'in the process of mixing cement/concrete'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.30701518058776855, 'start': 193, 'end': 222, 'answer': 'Home Depot  Store Number 6555'} --- Expected: the garden center
# Prediction: {'score': 0.05120723322033882, 'start': 279, 'end': 349, 'answer': 'between the excavation wall and the  north wall of the inlet structure'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.17506489157676697, 'start': 660, 'end': 666, 'answer': 'buried'} --- Expected: trench
# Prediction: {'score': 0.10103307664394379, 'start': 42, 'end': 80, 'answer': 'building a wood frame detached  garage'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.024857312440872192, 'start': 150, 'end': 167, 'answer': 'trenching project'} --- Expected: in the trench
# Prediction: {'score': 0.2054760456085205, 'start': 41, 'end': 49, 'answer': 'a trench'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.1650959551334381, 'start': 134, 'end': 150, 'answer': '8 ft deep trench'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.05483754351735115, 'start': 104, 'end': 133, 'answer': 'a tunnel underneath a highway'} --- Expected: tunnel underneath a highway
# Prediction: {'score': 0.40235579013824463, 'start': 116, 'end': 141, 'answer': 'residential swimming pool'} --- Expected: a residential swimming pool
#
# Question: Where?
# F1 score: 16.191573132749603/25
# Exact match: 14/25
# Prediction: {'score': 0.5052732825279236, 'start': 284, 'end': 322, 'answer': 'St. James hospital in  Chicago Heights'} --- Expected: a bathroom  facility
# Prediction: {'score': 0.20309896767139435, 'start': 66, 'end': 88, 'answer': 'Midwest  Masonry  Inc.'} --- Expected: mixing cement/concrete
# Prediction: {'score': 0.12794078886508942, 'start': 250, 'end': 277, 'answer': 'approximately one mile away'} --- Expected: one mile away
# Prediction: {'score': 0.1304030418395996, 'start': 183, 'end': 234, 'answer': 'in the emergency shoulder of an interstate  highway'} --- Expected: the emergency shoulder of an interstate  highway
# Prediction: {'score': 0.06188075616955757, 'start': 250, 'end': 301, 'answer': 'Utah County line to 12300 South in Salt Lake County'} --- Expected: Interstate 15 (I-15)  and approximately 14100 South
# Prediction: {'score': 0.14857755601406097, 'start': 279, 'end': 349, 'answer': 'between the excavation wall and the  north wall of the inlet structure'} --- Expected: G-2 drainage inlet structure
# Prediction: {'score': 0.03666674345731735, 'start': 46, 'end': 113, 'answer': 'Employee #1 was repairing a  pipeline for a new housing development'} --- Expected: trench
# Prediction: {'score': 0.29579657316207886, 'start': 303, 'end': 320, 'answer': 'a  local hospital'} --- Expected: a wood frame detached  garage
# Prediction: {'score': 0.0983428880572319, 'start': 655, 'end': 671, 'answer': 'a local hospital'} --- Expected: in the trench
# Prediction: {'score': 0.034594208002090454, 'start': 385, 'end': 413, 'answer': 'relocated to a care facility'} --- Expected: in a trench  at a depth of 18 feet
# Prediction: {'score': 0.06031370535492897, 'start': 287, 'end': 300, 'answer': 'Morton County'} --- Expected: in an approximately 8 ft deep trench
# Prediction: {'score': 0.28521329164505005, 'start': 116, 'end': 141, 'answer': 'residential swimming pool'} --- Expected: a residential swimming pool

# %% [markdown]
# ### 5.3 Event

# %%
run(model, text, questions_event, expected_event)
# Out:
# Question: What?
# F1 score: 5.969571072202651/25
# Exact match: 3/25
# Prediction: {'score': 0.00557408481836319, 'start': 122, 'end': 145, 'answer': 'asphalt milling machine'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.030539458617568016, 'start': 1193, 'end': 1246, 'answer': 'Employee #1 attempted to load a number  5 700 Panther'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.02636348456144333, 'start': 51, 'end': 132, 'answer': 'Employee #1 of Midwest  Masonry  Inc.  was responsible for using the cement mixer'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.020424477756023407, 'start': 24, 'end': 81, 'answer': 'Employee #1  a "flagger" with Iowa Erosion Control   Inc.'} --- Expected: struck Employee #1
# Prediction: {'score': 0.06944622099399567, 'start': 80, 'end': 116, 'answer': 'a piece of traffic control equipment'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.022654393687844276, 'start': 239, 'end': 293, 'answer': 'The employee underwent surgery for a crushed left foot'} --- Expected: his left foot was struck by and run over by a loader
# Prediction: {'score': 0.06474276632070541, 'start': 896, 'end': 968, 'answer': 'He suffered a fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.021766524761915207, 'start': 91, 'end': 133, 'answer': 'removing temporary traffic control barrels'} --- Expected: struck by the  dump truck
# Prediction: {'score': 0.06919342279434204, 'start': 56, 'end': 108, 'answer': 'installing a running  line in an Alimack hoist tower'} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.007606266997754574, 'start': 149, 'end': 222, 'answer': 'exterior insulating finishing system on the Home Depot  Store Number 6555'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.007725191302597523, 'start': 332, 'end': 350, 'answer': '20-ton bottle jack'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.04678655415773392, 'start': 47, 'end': 112, 'answer': 'Employee #1 and a coworker were  stripping the interior form work'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.1219840943813324, 'start': 62, 'end': 113, 'answer': 'repairing a  pipeline for a new housing development'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.16404852271080017, 'start': 42, 'end': 80, 'answer': 'building a wood frame detached  garage'} --- Expected: The trusses collapsed   causing them to fall
# Prediction: {'score': 0.03165842965245247, 'start': 185, 'end': 232, 'answer': 'installing a 2-inch water line and tracer  wire'} --- Expected: the trench wall and  spoil pile collapsed  covering Employee #1
# Prediction: {'score': 0.02758035808801651, 'start': 92, 'end': 110, 'answer': 'a wood-framed wall'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.06470635533332825, 'start': 73, 'end': 113, 'answer': 'installing 8 in. diameter PVC sewer pipe'} --- Expected: the entire east  side caved in and buried Employee #1
# Prediction: {'score': 0.0045746020041406155, 'start': 46, 'end': 57, 'answer': 'Employee #1'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.008599134162068367, 'start': 70, 'end': 85, 'answer': 'a hopper  barge'} --- Expected: he drowned
# Prediction: {'score': 0.13784779608249664, 'start': 223, 'end': 280, 'answer': 'his fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.2335912436246872, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
# Prediction: {'score': 0.17280694842338562, 'start': 14, 'end': 64, 'answer': 'a diver  became caught in a coffer dam and drowned'} --- Expected: drowned
#
# Question: What is the event?
# F1 score: 2.341414141414141/25
# Exact match: 0/25
# Prediction: {'score': 0.003812236012890935, 'start': 25, 'end': 42, 'answer': 'November 10  2013'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.0356176495552063, 'start': 149, 'end': 187, 'answer': 'demolish the interiors of the building'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.1483924835920334, 'start': 24, 'end': 86, 'answer': 'Employee #1 had a seizure while utilizing a bathroom  facility'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.5558687448501587, 'start': 66, 'end': 88, 'answer': 'Midwest  Masonry  Inc.'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.03735562786459923, 'start': 24, 'end': 81, 'answer': 'Employee #1  a "flagger" with Iowa Erosion Control   Inc.'} --- Expected: struck Employee #1
# Prediction: {'score': 0.019064147025346756, 'start': 4, 'end': 17, 'answer': 'June 14  2011'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.05168163776397705, 'start': 142, 'end': 157, 'answer': 'tunnel pipeline'} --- Expected: his left foot was struck by and run over by a loader
# Prediction: {'score': 0.8128244876861572, 'start': 118, 'end': 133, 'answer': 'Birds Eye Foods'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.04601477086544037, 'start': 345, 'end': 391, 'answer': 'to replace damaged sections of the  Interstate'} --- Expected: struck by the  dump truck
# Prediction: {'score': 0.1525803804397583, 'start': 56, 'end': 108, 'answer': 'installing a running  line in an Alimack hoist tower'} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.0404558964073658, 'start': 4, 'end': 19, 'answer': 'August 24  2003'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.057335566729307175, 'start': 4, 'end': 77, 'answer': 'October 24  2008  Employee #1 was working inside the freestanding carport'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.032910384237766266, 'start': 47, 'end': 112, 'answer': 'Employee #1 and a coworker were  stripping the interior form work'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.11174767464399338, 'start': 62, 'end': 113, 'answer': 'repairing a  pipeline for a new housing development'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.1720954328775406, 'start': 42, 'end': 80, 'answer': 'building a wood frame detached  garage'} --- Expected: The trusses collapsed   causing them to fall
# Prediction: {'score': 0.14368335902690887, 'start': 150, 'end': 167, 'answer': 'trenching project'} --- Expected: the trench wall and  spoil pile collapsed  covering Employee #1
# Prediction: {'score': 0.02324068546295166, 'start': 4, 'end': 20, 'answer': 'November 6  2009'} --- Expected: the wall caved in on him
# Prediction: {'score': 0.08834149688482285, 'start': 45, 'end': 62, 'answer': 'construction site'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.027717845514416695, 'start': 26, 'end': 39, 'answer': 'July 12  2007'} --- Expected: the entire east  side caved in and buried Employee #1
# Prediction: {'score': 0.017212651669979095, 'start': 31, 'end': 44, 'answer': 'June 17  2010'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.10310473293066025, 'start': 29, 'end': 43, 'answer': 'April 18  2007'} --- Expected: he drowned
# Prediction: {'score': 0.11676011979579926, 'start': 117, 'end': 131, 'answer': 'Nickajack Lake'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.176194429397583, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
# Prediction: {'score': 0.43039947748184204, 'start': 116, 'end': 141, 'answer': 'residential swimming pool'} --- Expected: drowned
# Prediction: {'score': 0.21319402754306793, 'start': 16, 'end': 21, 'answer': 'diver'} --- Expected: drowned
#
# Question: What is the incident?
# F1 score: 14.752728047740835/25
# Exact match: 11/25
# Prediction: {'score': 0.2357252985239029, 'start': 1678, 'end': 1725, 'answer': 'the number  5 700 Panther fell and flipped over'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.1667044311761856, 'start': 24, 'end': 86, 'answer': 'Employee #1 had a seizure while utilizing a bathroom  facility'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.07613605260848999, 'start': 134, 'end': 185, 'answer': 'He was struck by  the cement mixer that tipped over'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.044197533279657364, 'start': 904, 'end': 943, 'answer': 'Employee #1 was killed  in the incident'} --- Expected: struck Employee #1
# Prediction: {'score': 0.03057522512972355, 'start': 331, 'end': 400, 'answer': 'The passenger vehicle struck the trailered equipment  and Employee #1'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.15213191509246826, 'start': 896, 'end': 968, 'answer': 'He suffered a fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.06585301458835602, 'start': 1191, 'end': 1219, 'answer': 'He was killed from  asphyxia'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.06843259185552597, 'start': 926, 'end': 944, 'answer': 'breaking his  neck'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.07802971452474594, 'start': 635, 'end': 672, 'answer': 'He sustained numerous bodily injuries'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.07478566467761993, 'start': 512, 'end': 535, 'answer': 'the north wall caved in'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.12715716660022736, 'start': 240, 'end': 314, 'answer': 'The wall fell on Employee #1  who sustained a compressed disc in his  back'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.1379721313714981, 'start': 1064, 'end': 1086, 'answer': 'capsized  both vessels'} --- Expected: he drowned
# Prediction: {'score': 0.16107295453548431, 'start': 223, 'end': 280, 'answer': 'his fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.3971632122993469, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
# Prediction: {'score': 0.4490753412246704, 'start': 14, 'end': 64, 'answer': 'a diver  became caught in a coffer dam and drowned'} --- Expected: drowned
#
# Question: What incident has the employee suffered?
# F1 score: 11.23278279691323/25
# Exact match: 6/25
# Prediction: {'score': 0.2074769288301468, 'start': 3316, 'end': 3333, 'answer': 'struck and thrown'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.2758226692676544, 'start': 1678, 'end': 1725, 'answer': 'the number  5 700 Panther fell and flipped over'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.3408440053462982, 'start': 42, 'end': 49, 'answer': 'seizure'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.1474076211452484, 'start': 250, 'end': 296, 'answer': 'bruises to his upper right thigh and right hip'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.4841229021549225, 'start': 920, 'end': 926, 'answer': 'killed'} --- Expected: struck Employee #1
# Prediction: {'score': 0.04025116190314293, 'start': 236, 'end': 279, 'answer': 'A driver of a passenger vehicle fell asleep'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.36852335929870605, 'start': 910, 'end': 968, 'answer': 'fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.09833507984876633, 'start': 283, 'end': 320, 'answer': "severing Employee #1's right  big toe"} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.5475271344184875, 'start': 1211, 'end': 1219, 'answer': 'asphyxia'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.319343239068985, 'start': 926, 'end': 944, 'answer': 'breaking his  neck'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.2849978506565094, 'start': 648, 'end': 672, 'answer': 'numerous bodily injuries'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.10421450436115265, 'start': 203, 'end': 224, 'answer': 'The trusses collapsed'} --- Expected: The trusses collapsed   causing them to fall
# Prediction: {'score': 0.16578559577465057, 'start': 437, 'end': 478, 'answer': 'the trench wall and  spoil pile collapsed'} --- Expected: the trench wall and  spoil pile collapsed  covering Employee #1
# Prediction: {'score': 0.4278535842895508, 'start': 284, 'end': 314, 'answer': 'a compressed disc in his  back'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.10255992412567139, 'start': 213, 'end': 254, 'answer': 'the entire east  side caved in and buried'} --- Expected: the entire east  side caved in and buried Employee #1
# Prediction: {'score': 0.3002251088619232, 'start': 677, 'end': 683, 'answer': 'killed'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.11637350171804428, 'start': 1384, 'end': 1391, 'answer': 'drowned'} --- Expected: he drowned
# Prediction: {'score': 0.2909523844718933, 'start': 227, 'end': 280, 'answer': 'fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.22626999020576477, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
#
# Question: What incident has the employee experienced?
# F1 score: 12.250945190075623/25
# Exact match: 8/25
# Prediction: {'score': 0.26235857605934143, 'start': 1678, 'end': 1725, 'answer': 'the number  5 700 Panther fell and flipped over'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.28946805000305176, 'start': 42, 'end': 49, 'answer': 'seizure'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.09467574208974838, 'start': 141, 'end': 185, 'answer': 'struck by  the cement mixer that tipped over'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.3417811095714569, 'start': 920, 'end': 926, 'answer': 'killed'} --- Expected: struck Employee #1
# Prediction: {'score': 0.06967458128929138, 'start': 236, 'end': 279, 'answer': 'A driver of a passenger vehicle fell asleep'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.13778647780418396, 'start': 910, 'end': 968, 'answer': 'fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.15690070390701294, 'start': 1211, 'end': 1219, 'answer': 'asphyxia'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.13254426419734955, 'start': 926, 'end': 944, 'answer': 'breaking his  neck'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.10939545184373856, 'start': 635, 'end': 672, 'answer': 'He sustained numerous bodily injuries'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.14310474693775177, 'start': 173, 'end': 201, 'answer': 'the trusses started buckling'} --- Expected: The trusses collapsed   causing them to fall
# Prediction: {'score': 0.17410090565681458, 'start': 437, 'end': 478, 'answer': 'the trench wall and  spoil pile collapsed'} --- Expected: the trench wall and  spoil pile collapsed  covering Employee #1
# Prediction: {'score': 0.13349011540412903, 'start': 284, 'end': 314, 'answer': 'a compressed disc in his  back'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.20442092418670654, 'start': 661, 'end': 683, 'answer': 'Employee #1 was killed'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.02764846943318844, 'start': 1384, 'end': 1391, 'answer': 'drowned'} --- Expected: he drowned
# Prediction: {'score': 0.33699890971183777, 'start': 227, 'end': 280, 'answer': 'fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.28925612568855286, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
# Prediction: {'score': 0.4644392728805542, 'start': 14, 'end': 64, 'answer': 'a diver  became caught in a coffer dam and drowned'} --- Expected: drowned
#
# Question: What incident has the employee experienced? Mention if it is the employee #1 that has experienced the incident.
# F1 score: 11.135786435786436/25
# Exact match: 5/25
# Prediction: {'score': 0.06671508401632309, 'start': 3316, 'end': 3333, 'answer': 'struck and thrown'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.012635879218578339, 'start': 2027, 'end': 2066, 'answer': 'serious fracture injury to his left leg'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.265705943107605, 'start': 42, 'end': 49, 'answer': 'seizure'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.07906043529510498, 'start': 134, 'end': 185, 'answer': 'He was struck by  the cement mixer that tipped over'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.07638777792453766, 'start': 920, 'end': 926, 'answer': 'killed'} --- Expected: struck Employee #1
# Prediction: {'score': 0.04341698810458183, 'start': 236, 'end': 279, 'answer': 'A driver of a passenger vehicle fell asleep'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.13537108898162842, 'start': 807, 'end': 841, 'answer': 'Employee #1 fell off the dock lock'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.041779775172472, 'start': 283, 'end': 320, 'answer': "severing Employee #1's right  big toe"} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.021154360845685005, 'start': 1021, 'end': 1072, 'answer': 'Employee #1 became entangled in a  sheet of plastic'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.020641295239329338, 'start': 926, 'end': 944, 'answer': 'breaking his  neck'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.13959245383739471, 'start': 512, 'end': 535, 'answer': 'the north wall caved in'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.19112873077392578, 'start': 173, 'end': 201, 'answer': 'the trusses started buckling'} --- Expected: The trusses collapsed   causing them to fall
# Prediction: {'score': 0.06416403502225876, 'start': 437, 'end': 478, 'answer': 'the trench wall and  spoil pile collapsed'} --- Expected: the trench wall and  spoil pile collapsed  covering Employee #1
# Prediction: {'score': 0.03090173937380314, 'start': 68, 'end': 110, 'answer': 'trying to  stand on end a wood-framed wall'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.2552606463432312, 'start': 638, 'end': 659, 'answer': 'sheared and collapsed'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.04279443994164467, 'start': 45, 'end': 104, 'answer': 'Employee #1 had accessed a hopper  barge to release a cable'} --- Expected: he drowned
# Prediction: {'score': 0.3338991105556488, 'start': 227, 'end': 280, 'answer': 'fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.37280458211898804, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
# Prediction: {'score': 0.29316508769989014, 'start': 104, 'end': 175, 'answer': 'went into a residential swimming pool while on lunch  break and drowned'} --- Expected: drowned
# Prediction: {'score': 0.5997410416603088, 'start': 14, 'end': 64, 'answer': 'a diver  became caught in a coffer dam and drowned'} --- Expected: drowned
#
# Question: Identify the incident that occurred.
# F1 score: 13.534240652782852/25
# Exact match: 8/25
# Prediction: {'score': 0.017444880679249763, 'start': 3130, 'end': 3205, 'answer': 'a Chevrolet Tahoe came down  the inside lane where Employee #1 was standing'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.10329671949148178, 'start': 1678, 'end': 1725, 'answer': 'the number  5 700 Panther fell and flipped over'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.07623397558927536, 'start': 24, 'end': 86, 'answer': 'Employee #1 had a seizure while utilizing a bathroom  facility'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.07484792172908783, 'start': 134, 'end': 185, 'answer': 'He was struck by  the cement mixer that tipped over'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.02880319394171238, 'start': 904, 'end': 943, 'answer': 'Employee #1 was killed  in the incident'} --- Expected: struck Employee #1
# Prediction: {'score': 0.045907557010650635, 'start': 236, 'end': 279, 'answer': 'A driver of a passenger vehicle fell asleep'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.051313892006874084, 'start': 896, 'end': 968, 'answer': 'He suffered a fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.01880078762769699, 'start': 437, 'end': 503, 'answer': 'the coworker inadvertently came  into contact with the down button'} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.05844144523143768, 'start': 1211, 'end': 1220, 'answer': 'asphyxia.'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.04490687698125839, 'start': 806, 'end': 862, 'answer': 'the carport structure shifted off the temporary supports'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.09590645134449005, 'start': 512, 'end': 535, 'answer': 'the north wall caved in'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.039946943521499634, 'start': 240, 'end': 314, 'answer': 'The wall fell on Employee #1  who sustained a compressed disc in his  back'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.0660153180360794, 'start': 638, 'end': 659, 'answer': 'sheared and collapsed'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.06912349164485931, 'start': 1064, 'end': 1086, 'answer': 'capsized  both vessels'} --- Expected: he drowned
# Prediction: {'score': 0.07471640408039093, 'start': 223, 'end': 280, 'answer': 'his fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.3368929326534271, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
# Prediction: {'score': 0.32550814747810364, 'start': 14, 'end': 64, 'answer': 'a diver  became caught in a coffer dam and drowned'} --- Expected: drowned
#
# Question: Identify and summerize the incident that occurred.
# F1 score: 13.54782608695652/25
# Exact match: 11/25
# Prediction: {'score': 0.0001343706389889121, 'start': 2653, 'end': 2660, 'answer': 'traffic'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.0008333108853548765, 'start': 1678, 'end': 1726, 'answer': 'the number  5 700 Panther fell and flipped over.'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.02110547013580799, 'start': 88, 'end': 129, 'answer': 'The employee has past history of seizures'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.014368923380970955, 'start': 134, 'end': 185, 'answer': 'He was struck by  the cement mixer that tipped over'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.00983638595789671, 'start': 718, 'end': 743, 'answer': 'The Initial investigation'} --- Expected: struck Employee #1
# Prediction: {'score': 0.011369062587618828, 'start': 331, 'end': 400, 'answer': 'The passenger vehicle struck the trailered equipment  and Employee #1'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.030114397406578064, 'start': 184, 'end': 237, 'answer': 'his left foot was struck by and run over by a loader.'} --- Expected: his left foot was struck by and run over by a loader
# Prediction: {'score': 0.005352773703634739, 'start': 807, 'end': 841, 'answer': 'Employee #1 fell off the dock lock'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.017019769176840782, 'start': 4, 'end': 19, 'answer': 'August 24  2003'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.0057316310703754425, 'start': 4, 'end': 20, 'answer': 'October 24  2008'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.010727099142968655, 'start': 632, 'end': 667, 'answer': 'Employee #1 was killed when buried.'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.01872997172176838, 'start': 216, 'end': 238, 'answer': 'he lost control  of it'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.019552268087863922, 'start': 26, 'end': 39, 'answer': 'July 12  2007'} --- Expected: the entire east  side caved in and buried Employee #1
# Prediction: {'score': 0.020756015554070473, 'start': 661, 'end': 684, 'answer': 'Employee #1 was killed.'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.005870616529136896, 'start': 1064, 'end': 1086, 'answer': 'capsized  both vessels'} --- Expected: he drowned
# Prediction: {'score': 0.011380384676158428, 'start': 223, 'end': 280, 'answer': 'his fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.1370154321193695, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
#
# Question: Identify and summerize the incident that the employee experienced.
# F1 score: 13.452212051868802/25
# Exact match: 10/25
# Prediction: {'score': 0.00283067231066525, 'start': 276, 'end': 347, 'answer': 'standing on the  ground  checking the depth of the cut into the asphalt'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.0019558542408049107, 'start': 1678, 'end': 1725, 'answer': 'the number  5 700 Panther fell and flipped over'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.0852406695485115, 'start': 88, 'end': 129, 'answer': 'The employee has past history of seizures'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.025119731202721596, 'start': 134, 'end': 185, 'answer': 'He was struck by  the cement mixer that tipped over'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.03420684114098549, 'start': 904, 'end': 943, 'answer': 'Employee #1 was killed  in the incident'} --- Expected: struck Employee #1
# Prediction: {'score': 0.02558891475200653, 'start': 402, 'end': 425, 'answer': 'Employee #1 was killed.'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.06654008477926254, 'start': 184, 'end': 237, 'answer': 'his left foot was struck by and run over by a loader.'} --- Expected: his left foot was struck by and run over by a loader
# Prediction: {'score': 0.018292641267180443, 'start': 896, 'end': 968, 'answer': 'He suffered a fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.015422473661601543, 'start': 1191, 'end': 1219, 'answer': 'He was killed from  asphyxia'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.003028841922059655, 'start': 22, 'end': 106, 'answer': 'Employee #1 was working inside the freestanding carport  that was under construction'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.03702200576663017, 'start': 632, 'end': 667, 'answer': 'Employee #1 was killed when buried.'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.023032939061522484, 'start': 216, 'end': 238, 'answer': 'he lost control  of it'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.08838599920272827, 'start': 661, 'end': 684, 'answer': 'Employee #1 was killed.'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.00552892591804266, 'start': 1064, 'end': 1086, 'answer': 'capsized  both vessels'} --- Expected: he drowned
# Prediction: {'score': 0.02380352094769478, 'start': 223, 'end': 280, 'answer': 'his fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.16586104035377502, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
# Prediction: {'score': 0.16441971063613892, 'start': 14, 'end': 64, 'answer': 'a diver  became caught in a coffer dam and drowned'} --- Expected: drowned
#
# Question: Identify and summerize the consequences of the incident.
# F1 score: 9.845585190597978/25
# Exact match: 7/25
# Prediction: {'score': 0.0003482945030555129, 'start': 3529, 'end': 3556, 'answer': 'severe trauma   lacerations'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.0025580194778740406, 'start': 1678, 'end': 1725, 'answer': 'the number  5 700 Panther fell and flipped over'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.04763224720954895, 'start': 233, 'end': 251, 'answer': 'paramedics arrived'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.04622330144047737, 'start': 229, 'end': 296, 'answer': 'Employee #1 suffered bruises to his upper right thigh and right hip'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.031403958797454834, 'start': 758, 'end': 841, 'answer': 'warning signs  were posted along the highway  cones and other markings were present'} --- Expected: struck Employee #1
# Prediction: {'score': 0.06148136407136917, 'start': 402, 'end': 425, 'answer': 'Employee #1 was killed.'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.03528748080134392, 'start': 184, 'end': 237, 'answer': 'his left foot was struck by and run over by a loader.'} --- Expected: his left foot was struck by and run over by a loader
# Prediction: {'score': 0.16809500753879547, 'start': 896, 'end': 968, 'answer': 'He suffered a fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.06518352776765823, 'start': 1087, 'end': 1110, 'answer': 'Employee #1 was killed.'} --- Expected: struck by the  dump truck
# Prediction: {'score': 0.028080418705940247, 'start': 437, 'end': 503, 'answer': 'the coworker inadvertently came  into contact with the down button'} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.031347304582595825, 'start': 986, 'end': 1019, 'answer': 'four employees fled from the area'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.01752009056508541, 'start': 926, 'end': 945, 'answer': 'breaking his  neck.'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.23488017916679382, 'start': 635, 'end': 672, 'answer': 'He sustained numerous bodily injuries'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.04892481490969658, 'start': 632, 'end': 667, 'answer': 'Employee #1 was killed when buried.'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.1839943528175354, 'start': 282, 'end': 339, 'answer': "Employee #1's right  leg was fractured in multiple places"} --- Expected: the wall caved in on him
# Prediction: {'score': 0.03488808497786522, 'start': 240, 'end': 314, 'answer': 'The wall fell on Employee #1  who sustained a compressed disc in his  back'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.047398097813129425, 'start': 661, 'end': 684, 'answer': 'Employee #1 was killed.'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.3685625493526459, 'start': 1064, 'end': 1086, 'answer': 'capsized  both vessels'} --- Expected: he drowned
# Prediction: {'score': 0.07126613706350327, 'start': 557, 'end': 584, 'answer': 'drowned in 60 feet of water'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.15140870213508606, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
#
# Question: What is the injury that the employee has suffered?
# F1 score: 7.850108225108224/25
# Exact match: 5/25
# Prediction: {'score': 0.16268686950206757, 'start': 3529, 'end': 3604, 'answer': 'severe trauma   lacerations  fractures  and contusions to the body and head'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.2547832429409027, 'start': 2027, 'end': 2066, 'answer': 'serious fracture injury to his left leg'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.2254086434841156, 'start': 42, 'end': 49, 'answer': 'seizure'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.6156601905822754, 'start': 250, 'end': 296, 'answer': 'bruises to his upper right thigh and right hip'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.463655948638916, 'start': 920, 'end': 926, 'answer': 'killed'} --- Expected: struck Employee #1
# Prediction: {'score': 0.31423425674438477, 'start': 418, 'end': 424, 'answer': 'killed'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.08513488620519638, 'start': 184, 'end': 197, 'answer': 'his left foot'} --- Expected: his left foot was struck by and run over by a loader
# Prediction: {'score': 0.4753415286540985, 'start': 910, 'end': 968, 'answer': 'fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.2060461938381195, 'start': 1103, 'end': 1109, 'answer': 'killed'} --- Expected: struck by the  dump truck
# Prediction: {'score': 0.49278518557548523, 'start': 306, 'end': 320, 'answer': 'right  big toe'} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.6196732521057129, 'start': 1211, 'end': 1219, 'answer': 'asphyxia'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.5267317295074463, 'start': 926, 'end': 944, 'answer': 'breaking his  neck'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.4972982704639435, 'start': 648, 'end': 672, 'answer': 'numerous bodily injuries'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.38261017203330994, 'start': 264, 'end': 284, 'answer': 'unspecified injuries'} --- Expected: The trusses collapsed   causing them to fall
# Prediction: {'score': 0.09390170127153397, 'start': 724, 'end': 728, 'answer': 'died'} --- Expected: the trench wall and  spoil pile collapsed  covering Employee #1
# Prediction: {'score': 0.21411925554275513, 'start': 296, 'end': 339, 'answer': 'right  leg was fractured in multiple places'} --- Expected: the wall caved in on him
# Prediction: {'score': 0.5252875685691833, 'start': 284, 'end': 314, 'answer': 'a compressed disc in his  back'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.13436557352542877, 'start': 638, 'end': 659, 'answer': 'sheared and collapsed'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.13254359364509583, 'start': 223, 'end': 280, 'answer': 'his fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.26139670610427856, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
#
# Question: what caused the injury?
# F1 score: 6.380735930735931/25
# Exact match: 1/25
# Prediction: {'score': 0.03606373444199562, 'start': 3132, 'end': 3147, 'answer': 'Chevrolet Tahoe'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.08137939125299454, 'start': 2027, 'end': 2066, 'answer': 'serious fracture injury to his left leg'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.2538641691207886, 'start': 42, 'end': 49, 'answer': 'seizure'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.20906075835227966, 'start': 156, 'end': 226, 'answer': 'cement mixer that tipped over in the process of mixing cement/concrete'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.2121327817440033, 'start': 279, 'end': 291, 'answer': 'A semi-truck'} --- Expected: struck Employee #1
# Prediction: {'score': 0.17542093992233276, 'start': 236, 'end': 279, 'answer': 'A driver of a passenger vehicle fell asleep'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.6848985552787781, 'start': 228, 'end': 236, 'answer': 'a loader'} --- Expected: his left foot was struck by and run over by a loader
# Prediction: {'score': 0.43324241042137146, 'start': 910, 'end': 968, 'answer': 'fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.35829710960388184, 'start': 1075, 'end': 1085, 'answer': 'dump truck'} --- Expected: struck by the  dump truck
# Prediction: {'score': 0.15281978249549866, 'start': 437, 'end': 503, 'answer': 'the coworker inadvertently came  into contact with the down button'} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.7275902032852173, 'start': 1211, 'end': 1219, 'answer': 'asphyxia'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.36093640327453613, 'start': 806, 'end': 862, 'answer': 'the carport structure shifted off the temporary supports'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.17449027299880981, 'start': 490, 'end': 530, 'answer': 'the north wall developed vertical cracks'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.1718020737171173, 'start': 206, 'end': 253, 'answer': 'a separation between some  previously laid pipe'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.5290461182594299, 'start': 203, 'end': 224, 'answer': 'The trusses collapsed'} --- Expected: The trusses collapsed   causing them to fall
# Prediction: {'score': 0.255389541387558, 'start': 437, 'end': 478, 'answer': 'the trench wall and  spoil pile collapsed'} --- Expected: the trench wall and  spoil pile collapsed  covering Employee #1
# Prediction: {'score': 0.2469376176595688, 'start': 286, 'end': 314, 'answer': 'compressed disc in his  back'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.19086848199367523, 'start': 213, 'end': 243, 'answer': 'the entire east  side caved in'} --- Expected: the entire east  side caved in and buried Employee #1
# Prediction: {'score': 0.310048371553421, 'start': 638, 'end': 659, 'answer': 'sheared and collapsed'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.17593619227409363, 'start': 1064, 'end': 1086, 'answer': 'capsized  both vessels'} --- Expected: he drowned
# Prediction: {'score': 0.39597153663635254, 'start': 223, 'end': 280, 'answer': 'his fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.516755998134613, 'start': 173, 'end': 185, 'answer': 'a rain storm'} --- Expected: drowning Employee #1
# Prediction: {'score': 0.13117091357707977, 'start': 128, 'end': 141, 'answer': 'swimming pool'} --- Expected: drowned
# Prediction: {'score': 0.47556015849113464, 'start': 40, 'end': 52, 'answer': 'a coffer dam'} --- Expected: drowned
#
# Question: What is the cause of the incident?
# F1 score: 10.644362883493319/25
# Exact match: 6/25
# Prediction: {'score': 0.038667939603328705, 'start': 3316, 'end': 3333, 'answer': 'struck and thrown'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.19125507771968842, 'start': 1678, 'end': 1725, 'answer': 'the number  5 700 Panther fell and flipped over'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.198801651597023, 'start': 42, 'end': 49, 'answer': 'seizure'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.07249265909194946, 'start': 134, 'end': 185, 'answer': 'He was struck by  the cement mixer that tipped over'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.12411775439977646, 'start': 920, 'end': 926, 'answer': 'killed'} --- Expected: struck Employee #1
# Prediction: {'score': 0.19396597146987915, 'start': 268, 'end': 279, 'answer': 'fell asleep'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.33861416578292847, 'start': 910, 'end': 968, 'answer': 'fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.11583814024925232, 'start': 437, 'end': 503, 'answer': 'the coworker inadvertently came  into contact with the down button'} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.5279324650764465, 'start': 1211, 'end': 1219, 'answer': 'asphyxia'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.11821412295103073, 'start': 926, 'end': 944, 'answer': 'breaking his  neck'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.1995297223329544, 'start': 490, 'end': 530, 'answer': 'the north wall developed vertical cracks'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.15780015289783478, 'start': 512, 'end': 535, 'answer': 'the north wall caved in'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.22166408598423004, 'start': 203, 'end': 224, 'answer': 'The trusses collapsed'} --- Expected: The trusses collapsed   causing them to fall
# Prediction: {'score': 0.22109432518482208, 'start': 437, 'end': 478, 'answer': 'the trench wall and  spoil pile collapsed'} --- Expected: the trench wall and  spoil pile collapsed  covering Employee #1
# Prediction: {'score': 0.09268832206726074, 'start': 284, 'end': 314, 'answer': 'a compressed disc in his  back'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.24061349034309387, 'start': 638, 'end': 659, 'answer': 'sheared and collapsed'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.20578064024448395, 'start': 1064, 'end': 1086, 'answer': 'capsized  both vessels'} --- Expected: he drowned
# Prediction: {'score': 0.2818027138710022, 'start': 223, 'end': 280, 'answer': 'his fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.4216962158679962, 'start': 173, 'end': 185, 'answer': 'a rain storm'} --- Expected: drowning Employee #1
#
# Question: What is the cause of the injury?
# F1 score: 9.13668831168831/25
# Exact match: 5/25
# Prediction: {'score': 0.08083385974168777, 'start': 3529, 'end': 3604, 'answer': 'severe trauma   lacerations  fractures  and contusions to the body and head'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.2965989410877228, 'start': 2027, 'end': 2066, 'answer': 'serious fracture injury to his left leg'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.3427324593067169, 'start': 42, 'end': 49, 'answer': 'seizure'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.08537214994430542, 'start': 250, 'end': 257, 'answer': 'bruises'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.06836991012096405, 'start': 920, 'end': 926, 'answer': 'killed'} --- Expected: struck Employee #1
# Prediction: {'score': 0.14263439178466797, 'start': 236, 'end': 279, 'answer': 'A driver of a passenger vehicle fell asleep'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.5945244431495667, 'start': 910, 'end': 968, 'answer': 'fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.07899349182844162, 'start': 437, 'end': 503, 'answer': 'the coworker inadvertently came  into contact with the down button'} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.8637946248054504, 'start': 1211, 'end': 1219, 'answer': 'asphyxia'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.17993555963039398, 'start': 926, 'end': 944, 'answer': 'breaking his  neck'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.09350473433732986, 'start': 490, 'end': 530, 'answer': 'the north wall developed vertical cracks'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.17800138890743256, 'start': 512, 'end': 535, 'answer': 'the north wall caved in'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.2542969286441803, 'start': 203, 'end': 224, 'answer': 'The trusses collapsed'} --- Expected: The trusses collapsed   causing them to fall
# Prediction: {'score': 0.20167583227157593, 'start': 437, 'end': 478, 'answer': 'the trench wall and  spoil pile collapsed'} --- Expected: the trench wall and  spoil pile collapsed  covering Employee #1
# Prediction: {'score': 0.3857012391090393, 'start': 286, 'end': 314, 'answer': 'compressed disc in his  back'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.13705408573150635, 'start': 213, 'end': 243, 'answer': 'the entire east  side caved in'} --- Expected: the entire east  side caved in and buried Employee #1
# Prediction: {'score': 0.3686683177947998, 'start': 638, 'end': 659, 'answer': 'sheared and collapsed'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.09198755025863647, 'start': 1064, 'end': 1086, 'answer': 'capsized  both vessels'} --- Expected: he drowned
# Prediction: {'score': 0.3723471164703369, 'start': 227, 'end': 280, 'answer': 'fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.3701727092266083, 'start': 173, 'end': 185, 'answer': 'a rain storm'} --- Expected: drowning Employee #1
#
# Question: Who was involved in the incident and what happened?
# F1 score: 8.149422799422798/25
# Exact match: 3/25
# Prediction: {'score': 0.19730064272880554, 'start': 44, 'end': 89, 'answer': 'Employee #1  with Villager  Construction Inc.'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.26897674798965454, 'start': 21, 'end': 32, 'answer': 'Employee #1'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.09852609038352966, 'start': 131, 'end': 189, 'answer': 'A coworker found Employee  #1 unresponsive  and called 911'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.31692883372306824, 'start': 51, 'end': 88, 'answer': 'Employee #1 of Midwest  Masonry  Inc.'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.26587483286857605, 'start': 904, 'end': 926, 'answer': 'Employee #1 was killed'} --- Expected: struck Employee #1
# Prediction: {'score': 0.13893038034439087, 'start': 19, 'end': 30, 'answer': 'Employee #1'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.02614007703959942, 'start': 896, 'end': 968, 'answer': 'He suffered a fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.06388957053422928, 'start': 1087, 'end': 1109, 'answer': 'Employee #1 was killed'} --- Expected: struck by the  dump truck
# Prediction: {'score': 0.07126227021217346, 'start': 24, 'end': 50, 'answer': 'Employee #1 and a coworker'} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.05946183577179909, 'start': 1021, 'end': 1032, 'answer': 'Employee #1'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.06776441633701324, 'start': 874, 'end': 944, 'answer': 'Employee #1 on the inside structure of the carport  breaking his  neck'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.08286304026842117, 'start': 47, 'end': 73, 'answer': 'Employee #1 and a coworker'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.25966334342956543, 'start': 18, 'end': 36, 'answer': 'Employee #1 and #2'} --- Expected: The trusses collapsed   causing them to fall
# Prediction: {'score': 0.05176623910665512, 'start': 22, 'end': 33, 'answer': 'Employee #1'} --- Expected: the wall caved in on him
# Prediction: {'score': 0.16870678961277008, 'start': 1, 'end': 12, 'answer': 'Employee #1'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.05085320398211479, 'start': 41, 'end': 52, 'answer': 'Employee #1'} --- Expected: the entire east  side caved in and buried Employee #1
# Prediction: {'score': 0.19821077585220337, 'start': 46, 'end': 102, 'answer': 'Employee #1  a plumber  and the  company general manager'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.047857899218797684, 'start': 45, 'end': 56, 'answer': 'Employee #1'} --- Expected: he drowned
# Prediction: {'score': 0.07305842638015747, 'start': 34, 'end': 45, 'answer': 'Employee #1'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.11940531432628632, 'start': 21, 'end': 32, 'answer': 'Employee #1'} --- Expected: drowning Employee #1
# Prediction: {'score': 0.7581639289855957, 'start': 51, 'end': 62, 'answer': 'Employee #1'} --- Expected: drowned
# Prediction: {'score': 0.5516698360443115, 'start': 1, 'end': 12, 'answer': 'Employee #1'} --- Expected: drowned
#
# Question: Summerize the incident
# F1 score: 7.166013071895424/25
# Exact match: 5/25
# Prediction: {'score': 0.0165473073720932, 'start': 25, 'end': 42, 'answer': 'November 10  2013'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.022941187024116516, 'start': 4, 'end': 19, 'answer': 'August 27  2012'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.12766778469085693, 'start': 4, 'end': 86, 'answer': 'September 19  2012  Employee #1 had a seizure while utilizing a bathroom  facility'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.0276316050440073, 'start': 33, 'end': 49, 'answer': 'November17  2010'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.07141158729791641, 'start': 904, 'end': 943, 'answer': 'Employee #1 was killed  in the incident'} --- Expected: struck Employee #1
# Prediction: {'score': 0.07804109156131744, 'start': 4, 'end': 17, 'answer': 'June 14  2011'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.044230520725250244, 'start': 31, 'end': 47, 'answer': 'February 6  2009'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.08078601956367493, 'start': 17, 'end': 35, 'answer': 'September 29  2011'} --- Expected: struck by the  dump truck
# Prediction: {'score': 0.02523219771683216, 'start': 4, 'end': 22, 'answer': 'September 30  2008'} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.06162800267338753, 'start': 4, 'end': 19, 'answer': 'August 24  2003'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.05608045682311058, 'start': 4, 'end': 20, 'answer': 'October 24  2008'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.15586741268634796, 'start': 31, 'end': 45, 'answer': 'August 9  2007'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.1013597846031189, 'start': 31, 'end': 44, 'answer': 'June 21  2011'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.06769311428070068, 'start': 31, 'end': 47, 'answer': 'November 9  2010'} --- Expected: the trench wall and  spoil pile collapsed  covering Employee #1
# Prediction: {'score': 0.04042287543416023, 'start': 240, 'end': 314, 'answer': 'The wall fell on Employee #1  who sustained a compressed disc in his  back'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.39275234937667847, 'start': 26, 'end': 39, 'answer': 'July 12  2007'} --- Expected: the entire east  side caved in and buried Employee #1
# Prediction: {'score': 0.1841171234846115, 'start': 31, 'end': 44, 'answer': 'June 17  2010'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.16143184900283813, 'start': 1064, 'end': 1086, 'answer': 'capsized  both vessels'} --- Expected: he drowned
# Prediction: {'score': 0.02160310186445713, 'start': 18, 'end': 32, 'answer': 'March 26  2012'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.2304149717092514, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
#
# Question: Summerize the incident that occurred
# F1 score: 9.819047619047618/25
# Exact match: 7/25
# Prediction: {'score': 0.006404186133295298, 'start': 25, 'end': 42, 'answer': 'November 10  2013'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.01935422047972679, 'start': 4, 'end': 19, 'answer': 'August 27  2012'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.15061695873737335, 'start': 4, 'end': 86, 'answer': 'September 19  2012  Employee #1 had a seizure while utilizing a bathroom  facility'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.0378209687769413, 'start': 134, 'end': 185, 'answer': 'He was struck by  the cement mixer that tipped over'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.06273022294044495, 'start': 4, 'end': 22, 'answer': 'September 26  2013'} --- Expected: struck Employee #1
# Prediction: {'score': 0.06878030300140381, 'start': 4, 'end': 17, 'answer': 'June 14  2011'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.04498686268925667, 'start': 807, 'end': 841, 'answer': 'Employee #1 fell off the dock lock'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.06038394197821617, 'start': 17, 'end': 35, 'answer': 'September 29  2011'} --- Expected: struck by the  dump truck
# Prediction: {'score': 0.09517782181501389, 'start': 4, 'end': 19, 'answer': 'August 24  2003'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.029124723747372627, 'start': 806, 'end': 862, 'answer': 'the carport structure shifted off the temporary supports'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.07882026582956314, 'start': 31, 'end': 45, 'answer': 'August 9  2007'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.03493855148553848, 'start': 31, 'end': 44, 'answer': 'June 21  2011'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.21313172578811646, 'start': 26, 'end': 39, 'answer': 'July 12  2007'} --- Expected: the entire east  side caved in and buried Employee #1
# Prediction: {'score': 0.05211601406335831, 'start': 31, 'end': 44, 'answer': 'June 17  2010'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.017862213775515556, 'start': 1064, 'end': 1086, 'answer': 'capsized  both vessels'} --- Expected: he drowned
# Prediction: {'score': 0.0266665518283844, 'start': 223, 'end': 280, 'answer': 'his fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.2499135434627533, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1
# Prediction: {'score': 0.045760378241539, 'start': 31, 'end': 49, 'answer': 'September 12  2006'} --- Expected: drowned
#
# Question: Summerize the incident and the consequences
# F1 score: 9.654351424364211/25
# Exact match: 7/25
# Prediction: {'score': 0.005781015381217003, 'start': 3529, 'end': 3604, 'answer': 'severe trauma   lacerations  fractures  and contusions to the body and head'} --- Expected: Employee #1  was struck and thrown
# Prediction: {'score': 0.007863071747124195, 'start': 1678, 'end': 1725, 'answer': 'the number  5 700 Panther fell and flipped over'} --- Expected: the Panther which weighed over 2 000  pounds fell on his left foot and pinned it
# Prediction: {'score': 0.013803278096020222, 'start': 4, 'end': 86, 'answer': 'September 19  2012  Employee #1 had a seizure while utilizing a bathroom  facility'} --- Expected: Employee #1 had a seizure
# Prediction: {'score': 0.04424659162759781, 'start': 229, 'end': 296, 'answer': 'Employee #1 suffered bruises to his upper right thigh and right hip'} --- Expected: He was struck by  the cement mixer
# Prediction: {'score': 0.026260092854499817, 'start': 718, 'end': 743, 'answer': 'The Initial investigation'} --- Expected: struck Employee #1
# Prediction: {'score': 0.01409075129777193, 'start': 4, 'end': 17, 'answer': 'June 14  2011'} --- Expected: The passenger vehicle struck the trailered equipment and Employee #1
# Prediction: {'score': 0.04708501324057579, 'start': 184, 'end': 237, 'answer': 'his left foot was struck by and run over by a loader.'} --- Expected: his left foot was struck by and run over by a loader
# Prediction: {'score': 0.10781588405370712, 'start': 896, 'end': 968, 'answer': 'He suffered a fractured pelvis  a  ruptured bladder  and leg vein damage'} --- Expected: Employee #1 fell off the dock lock and was  pinned between the loading dock and trailer
# Prediction: {'score': 0.007152855861932039, 'start': 437, 'end': 503, 'answer': 'the coworker inadvertently came  into contact with the down button'} --- Expected: The car suddenly descended a few inches
# Prediction: {'score': 0.02070961892604828, 'start': 788, 'end': 871, 'answer': 'The wind reached speeds in excess of 40 mph  and began collapsing the masonry piers'} --- Expected: 14-foot tall masonry pier  collapsed on him  crushing him
# Prediction: {'score': 0.013299125246703625, 'start': 806, 'end': 862, 'answer': 'the carport structure shifted off the temporary supports'} --- Expected: trapping Employee #1 on the inside structure of the carport
# Prediction: {'score': 0.04472355172038078, 'start': 635, 'end': 672, 'answer': 'He sustained numerous bodily injuries'} --- Expected: crushing Employee #1 against the south  wall
# Prediction: {'score': 0.03837291896343231, 'start': 512, 'end': 535, 'answer': 'the north wall caved in'} --- Expected: Employee #1 was killed when buried
# Prediction: {'score': 0.06406652927398682, 'start': 240, 'end': 314, 'answer': 'The wall fell on Employee #1  who sustained a compressed disc in his  back'} --- Expected: The wall fell on Employee #1
# Prediction: {'score': 0.046613242477178574, 'start': 26, 'end': 39, 'answer': 'July 12  2007'} --- Expected: the entire east  side caved in and buried Employee #1
# Prediction: {'score': 0.06897354871034622, 'start': 661, 'end': 684, 'answer': 'Employee #1 was killed.'} --- Expected: it sheared and collapsed
# Prediction: {'score': 0.2994822859764099, 'start': 1064, 'end': 1086, 'answer': 'capsized  both vessels'} --- Expected: he drowned
# Prediction: {'score': 0.016790172085165977, 'start': 223, 'end': 280, 'answer': 'his fall  arrest lanyard became tangled on a mooring post'} --- Expected: Employee  #1 sank and drowned in 60 feet of water
# Prediction: {'score': 0.2675327658653259, 'start': 173, 'end': 224, 'answer': 'a rain storm flooded the pipe  drowning Employee #1'} --- Expected: drowning Employee #1

# %% [markdown]
# ## Analyse
#
# Pour les trois questions, nous avons procédé de façon itérative, débutant avec les formulations les plus simples.
#
# ### Quand?
#
# Pour les questions sur le moment de l'incident, nous avons immédiatement obtenu des résultats satisfaisants avec 23/25 pour l'« exact match ». Les deux erreurs sont dues au fait que la date n'est pas indiquée dans le rapport d'incident. La réponse retournée devrait alors être vide, cependant, le modèle retourne toujours du texte. Nous avons essayé d'ajouter une instruction au modèle pour ne rien retourner si la réponse n'est pas trouvée, cependant, le modèle ne semble pas avoir une capacité avancée de suivi d'instructions. La réponse retournée est toujours la même, peu importe la formulation de la question. Pour ce type de question, le modèle semble donc être robuste à la formulation de la question. Pour obtenir 25/25, il faudrait donc utiliser une méthode externe au modèle, telle que refuser ou accepter les réponses basées sur leur score.
#
# ### Où?
#
# La deuxième question, "Où?", s'est avérée plus difficile que la première. Les réponses étant plus complexes, il n'est pas surprenant que les résultats soient inférieurs à la première question qui avait des dates clairement indiquées. Pour cette question, nous avons premièrement testé "Where did the event happen?" et "Where did the incident happen?" pour établir une référence pour les prochaines itérations. Nous avons ensuite testé différentes structures de questions telles que "[Verbe2] the place where the [nom] [verbe1].", "Where did the [nom] [verbe1]?" et "What place did the [nom] [verbe1]?" où [verbe1] est un choix parmi occurred, took place, was located, emerged, happened et [verbe2] est name, describe, find ou identify. Pour [nom], nous avons testé event et incident. La structure "[Verbe2] the place where the [nom] [verbe1]." a donné des résultats significativement inférieurs aux deux autres. Cela est probablement dû au fait que ce n'est pas formulé comme une question, mais plutôt comme une instruction. Les deux autres structures de questions ont peu d'impact sur les résultats. La meilleure question avec les données de test est "What place did the event occur?" avec un F1 score de 20.46/25 et un exact match de 17/25. Par contre, les autres alternatives sont relativement proches; le classement pourrait varier en utilisant un autre groupe de test. Surprenamment, la question contient une erreur, occurred devrait être occur, mais les résultats sont légèrement inférieurs si nous la corrigeons. Nous avons aussi testé simplement "Where?" ce qui donne de meilleurs résultats que le format par instruction, mais inférieurs à une question complète.
#
# La difficulté de la question vient probablement du fait que plusieurs endroits peuvent être donnés dans le rapport; le modèle doit ainsi être en mesure de trouver non seulement ce qui est un endroit, mais aussi l'endroit qui correspond à la question. Les résultats indiquent aussi que le modèle a obtenu certaines réponses partiellement bonnes, l'exact match étant inférieur au F1 score. Cela peut s'expliquer par le fait que le modèle pouvait retourner le bon endroit, mais ne fournissait pas exactement les informations attendues. Par exemple, pour un exemple, le modèle retourne "drainage inlet structure" alors que la réponse attendue était "G-2 drainage inlet structure". Le modèle a trouvé le bon endroit, mais il lui manque une information, ce qui lui donne un bon F1 score, mais pas un exact match.
#
# ### Quoi?
#
# Pour la description de l'incident, l'information a été beaucoup plus difficile à bien extraire. Pour trouver les bonnes informations, le modèle doit bien comprendre la question et le rapport. Contrairement à la deuxième question, le choix des mots a eu beaucoup d'impact. Dans un premier temps, nous avons testé "What is the event?" et "What is the incident?". Même s'il y a seulement un mot de différence entre les deux questions, la première a donné le pire résultat avec un F1 score de 2.34/25 et aucun exact match, et la deuxième est la meilleure parmi toutes les questions que nous avons testées avec un F1 score de 14.75/25 et un exact match de 11/25. Nous avons testé d'autres formulations et le format d'instructions donne de très bons résultats. Par exemple, "Identify and summarize the incident that occurred." donne un F1 score de 13.54/25 et un exact match de 11/25, ce qui est très près du meilleur résultat.
#
# ### Remarques générales
#
# Basé sur nos expérimentations, les conclusions que nous avons tirées sont que la clarté de l'information recherchée impacte considérablement la capacité du modèle à retrouver l'information. La réponse à la question "Quand?" est claire alors que la réponse au "Quoi?" est plus subtile. Il y a plusieurs façons de formuler l'information et la longueur est très variable. Deuxièmement, les instructions avec la question ont peu d'impact, surtout sur les questions les plus simples telles que le "Quand?". Le modèle est incapable de ne rien retourner; il trouvera toujours une information à retourner même si elle ne correspond pas à l'information recherchée. Finalement, le choix de la structure et des mots peut avoir un grand impact dans certains cas, alors qu'il importe peu dans les autres cas.
